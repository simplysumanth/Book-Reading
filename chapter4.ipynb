# %% [markdown]
# <a href="https://colab.research.google.com/github/simplysumanth/Book-Reading/blob/main/chapter4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Reading Images and DICOM Images

# %%
import imageio

# %%
im = imageio.imread('http://upload.wikimedia.org/wikipedia/commons/d/de/Wikipedia_Logo_1.0.png')

# %%
im
# Out:
# Array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
movie = imageio.get_reader('sample.mp4')
for i, im in enumerate(movie):
  print(i, im.size)

# %%
path = '/content/' 
dicom = imageio.read(path, 'DICOM')
dicom

# %%
import pydicom as dicom
import matplotlib.pylab as plt
import numpy as np

#img_path = '0002.DCM'
#base_path = '/content'
image = '/content/test.dcm'
#file_path = pydicom.data.data_manager.get_files(base_path, img_path)[0]
ds = dicom.dcmread(image)
#plt.imshow(ds.pixel_array)
ds_img = ds.pixel_array
#plt_ds = np.transpose(ds_img, (2,1,0))
plt.imshow(ds_img, cmap=plt.cm.bone)

# %%
print(ds)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.6655.2359.143589139661703926987776382874
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002, 0013) Implementation Version Name         SH: '0.5'
# (0002, 0016) Source Application Entity Title     AE: 'POSDA'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'HELIX']
# (0008, 0012) Instance Creation Date              DA: '20070404'
# ...

# %%
import torch

# %%
# ?torch.unsqueeze

# %%
x = torch.Tensor([1.,2.,3.,4.])
x.shape
# Out:
# torch.Size([4])

# %%
y = torch.unsqueeze(x,1)
y.shape
# Out:
# torch.Size([4, 1])

# %%
torch.squeeze(y).shape
# Out:
# torch.Size([4])

# %%
# ?torch.Tensor.view

# %%
v = torch.randn(4,4)
v.size()
# Out:
# torch.Size([4, 4])

# %%
w = v.view(16)
w.size()
# Out:
# torch.Size([16])

# %%
w = v.view(-1,1)
w.size()
# Out:
# torch.Size([16, 1])
